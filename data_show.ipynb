# %%
import pandas as pd
import matplotlib.pyplot as plt
# import pandas as pd

# %%
filename="/mnt/c/Users/survey/Documents/GitHub/GNSS_accel/ACCSTICK6-230322_164200_cut.csv"
filename=""
data = pd.read_csv(filename)

# %%
print(data)
# Out:
#      frame        dist0
# 0    631.0  2864.914795
# 1    632.0  2864.665527
# 2    633.0  2864.491455
# 3    634.0  2864.391113
# 4    635.0  2864.297119
# ..     ...          ...
# 265  896.0  2864.958008
# 266  897.0  2864.813232
# 267  898.0  2864.715088
# 268  899.0  2864.715820
# 269  900.0  2864.708252
#
# [270 rows x 2 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
fig, ax = plt.subplots()
ax.plot(data['No'],data['X'], label='X')
ax.plot(data['No'],data['Y'], label='Y')
# ax.legend()
# ax.set_xlabel('Year')
# ax.set_ylabel('Sales')
# ax.set_title('Sales Comparison')
plt.xlim(400000,500000)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
ax.plot(data['No'],data['X'], label='X')
ax.plot(data['No'],data['Y'], label='Y')
# ax.legend()
# ax.set_xlabel('Year')
# ax.set_ylabel('Sales')
# ax.set_title('Sales Comparison')
plt.xlim(390000,420000)
plt.ylim(-0.2,0.2)
# Out:
# (-0.2, 0.2)

# %%
fig, ax = plt.subplots()
ax.plot(data['No'],data['X'], label='X')
ax.plot(data['No'],data['Y'], label='Y')
# ax.legend()
# ax.set_xlabel('Year')
# ax.set_ylabel('Sales')
# ax.set_title('Sales Comparison')
plt.xlim(240000,280000)
# Out:
# (240000.0, 280000.0)

# %%
fig, ax = plt.subplots()
ax.plot(data['No'],data['X'], label='X')
ax.plot(data['No'],data['Y'], label='Y')
# ax.legend()
# ax.set_xlabel('Year')
# ax.set_ylabel('Sales')
# ax.set_title('Sales Comparison')
plt.xlim(210000,280000)
# Out:
# (210000.0, 280000.0)

# %%
fig, ax = plt.subplots()
ax.plot(data['No'],data['X'], label='X')
ax.plot(data['No'],data['Y'], label='Y')
# ax.legend()
# ax.set_xlabel('Year')
# ax.set_ylabel('Sales')
# ax.set_title('Sales Comparison')
plt.xlim(310000,380000)
# Out:
# (310000.0, 380000.0)

# %%
fig, ax = plt.subplots()
ax.plot(data['No'],data['X'], label='X')
ax.plot(data['No'],data['Y'], label='Y')
# ax.legend()
# ax.set_xlabel('Year')
# ax.set_ylabel('Sales')
# ax.set_title('Sales Comparison')
plt.xlim(380000,450000)
# Out:
# (380000.0, 450000.0)

# %%
data.plot(x='No', y='X')
plt.xlim(420000,450000)
plt.ylim(-1.0,1.0)
# Out:
# (-1.0, 1.0)

# %%
data.plot(x='No', y='X')
plt.xlim(350000,420000)
# plt.ylim(-1.0,1.0)
# Out:
# (350000.0, 420000.0)

# %%
data.plot(x='No', y='Y')
plt.xlim(420000,450000)
plt.ylim(-1.0,1.0)
# plt.xlim(420000,470000)
# Out:
# (-1.0, 1.0)

# %%
data.plot(x='No', y='Y')
plt.xlim(420000,470000)
plt.xlim(420000,470000)
# Out:
# (420000.0, 470000.0)

# %%
data.plot(x='No', y='Z')
plt.xlim(400000,500000)
# Out:
# (400000.0, 500000.0)

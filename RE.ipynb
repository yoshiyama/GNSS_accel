# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename="/mnt/c/Users/survey/Documents/GitHub/GNSS_accel/GX070226_swing_630-900_1-20230323_180454.pickle"
filename2="/mnt/c/Users/survey/Documents/GitHub/GNSS_accel/GX070226_swing_4206-4476_1-20230323_193522.pickle"

# %%
df1 = pd.read_pickle(filename)
df2 = pd.read_pickle(filename2)

# %%
df1
# Out:
#      frame        dist0
# 0    631.0  2864.914795
# 1    632.0  2864.665527
# 2    633.0  2864.491455
# 3    634.0  2864.391113
# 4    635.0  2864.297119
# ..     ...          ...
# 265  896.0  2864.958008
# 266  897.0  2864.813232
# 267  898.0  2864.715088
# 268  899.0  2864.715820
# 269  900.0  2864.708252
#
# [270 rows x 2 columns]

# %%
df1.plot(y='dist0')
plt.legend().remove()

# %%
df2
# Out:
#       frame        dist0        dist1        dist2        dist3        dist4  \
# 0    4207.0  3228.970947  2487.041016  3110.067627  2947.781982  2944.395508
# 1    4208.0  3228.970459  2487.046875  3110.067871  2947.773438  2944.390625
# 2    4209.0  3228.967285  2487.050049  3110.067871  2947.760010  2944.391357
# 3    4210.0  3228.958984  2487.041016  3110.060791  2947.764893  2944.373535
# 4    4211.0  3228.961914  2487.042725  3110.060791  2947.764893  2944.373535
# ..      ...          ...          ...          ...          ...          ...
# 265  4472.0  3229.205811  2487.196777  3110.051025  2947.912598  2944.365967
# 266  4473.0  3229.209717  2487.209229  3110.044922  2947.957275  2944.364014
# 267  4474.0  3229.159668  2487.254395  3110.010986  2947.929688  2944.340088
# 268  4475.0  3229.163086  2487.245117  3110.014404  2947.929199  2944.335693
# 269  4476.0  3229.140869  2487.168701  3110.036133  2947.929688  2944.280518
#
# ...

# %%
df2.plot(y='dist12')
plt.xlim(130,)
plt.ylim(2831.6,2833.6)
plt.legend().remove()
